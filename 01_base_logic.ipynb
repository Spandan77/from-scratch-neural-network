# %%
import random
import math
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
    return 1 / (1 + math.exp(-x))
def dsigmoid(x):
    s = sigmoid(x)
    return s * (1-s)

# %%
X = [
    [1, 1, 1, 0, 1, 0, 0, 1, 0], #T
    [1, 1, 1, 0, 1, 0, 1, 1, 0], #J
    [1, 1, 1, 1, 0, 1, 1, 1, 1]  #O
]
y = [
    [1, 0, 0],
    [0, 1, 0],
    [0, 0, 1]
]
learning_rate = 0.01

# %%
ill = len(X[0])
oll = len(y[0])

# %%
weights = [ [random.uniform(-1, 1) for i in range(ill)] for j in range(oll) ]
biases = [ random.uniform(-1, 1) for j in range(oll) ]
print(f'weights: {weights}\nbiases: {biases}')
# Out:
# weights: [[-0.1568451039992278, -0.896972908719954, -0.5836118269152994, -0.5830743508675895, 0.8181854800504078, -0.6544957750942293, 0.8994448207654488, 0.8203907600510632, 0.1714530114274766], [-0.03694359440558559, 0.9993132654582884, -0.8668165789395297, -0.7040206656111141, -0.2876119820942882, -0.13746219634332646, 0.2603406119611449, -0.625743875849625, -0.0057768508049023115], [-0.6169255633949893, -0.7423300786345184, -0.7443285253880756, -0.8866794727825051, 0.94078319549266, 0.21164015623521726, 0.6836999089257341, 0.6010777055362793, 0.5612165089596799]]
# biases: [-0.02983158298847144, 0.33679162997469514, -0.053096656790408536]

# %%
def predict(I):
    z = [ 
        sum([ I[i] * weights[j][i] for i in range(ill) ]) + biases[j] for j in range(oll)
    ]
    output = [ sigmoid(z[j]) for j in range(oll) ]
    return z, output

# %%
costHistory = []

cost = 1
while cost > 0.001:
    costs = []
    for p in range(X.__len__()):
        I = X[p]
        E = y[p]

        z, output = predict(I)
        # z = [ 
        #     sum([ I[i] * weights[j][i] for i in range(ill) ]) + biases[j] for j in range(oll)
        # ]
        # output = [ sigmoid(z[j]) for j in range(oll) ]

        Cw = [ [ 2 * (output[j]-E[j]) * dsigmoid(z[j]) * I[i] for i in range(ill) ] for j in range(oll) ]
        Cb = [ 2 * (output[j]-E[j]) * dsigmoid(z[j]) for j in range(oll) ]
        
        weights = [ [ weights[j][i] - Cw[j][i] * learning_rate for i in range(ill) ] for j in range(oll) ]
        biases = [ biases[j] - Cb[j] * learning_rate for j in range(oll) ]

        costs.append(sum([ math.pow(output[j]-E[j], 2) for j in range(oll) ]))

    cost = sum(costs)/len(costs)
    costHistory.append(cost)

print(f'Cost: {cost}')

# plt.subplot(1, 2, 1)
# plt.plot([i for i in range(len(costHistory))], costHistory)
# plt.title('Normal Scale')
# plt.xlabel('Number of Iterations')
# plt.ylabel('cost')

# plt.subplot(1, 2, 2)
# plt.loglog([i for i in range(len(costHistory))], costHistory)
# plt.title('Logarithmic Scale')
# plt.xlabel('Number of Iterations')
# plt.ylabel('cost')

# plt.show()
# Out:
# Cost: 0.0009999951202690428

# %%
c=0
t=0
accuracy=0

for i in range(100):
    test_inputs = [
        [
        random.uniform(0.8, 1),
        random.uniform(0.8, 1),
        random.uniform(0.8, 1),
        random.uniform(0, 0.2),
        random.uniform(0.8, 1),
        random.uniform(0, 0.2),
        random.uniform(0, 0.2),
        random.uniform(0.8, 1),
        random.uniform(0, 0.2),
        ],
        [
        random.uniform(0.8, 1),
        random.uniform(0.8, 1),
        random.uniform(0.8, 1),
        random.uniform(0, 0.2),
        random.uniform(0.8, 1),
        random.uniform(0, 0.2),
        random.uniform(0.8, 1),
        random.uniform(0.8, 1),
        random.uniform(0, 0.2),
        ],
        [
        random.uniform(0.8, 1),
        random.uniform(0.8, 1),
        random.uniform(0.8, 1),
        random.uniform(0.8, 1),
        random.uniform(0, 0.2),
        random.uniform(0.8, 1),
        random.uniform(0.8, 1),
        random.uniform(0.8, 1),
        random.uniform(0.8, 1),
        ]
    ]
    answer = ['T', 'J', 'O']
    
    t = random.randrange(3)
    test_input = test_inputs[t]
    
    z, o = predict(test_input)
    # print(o)
    prediction = o.index(max(o))
    c += 1 if prediction == t else 0
    t += 1
    # print(f'Predicted: {answer[prediction]}\nActual: {answer[t]}')

accuracy = c/t
accuracy
# Out:
# 33.333333333333336
